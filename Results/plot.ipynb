# %%
import matplotlib.pyplot as plt


accuracy_avg1 = [0.2714843749999999, 0.3069335937499999, 0.3234374999999999]
accuracy_avg2 = [0.30732421874999993, 0.33994140624999997, 0.3520507812499999]
accuracy_avg3 = [0.2943359375, 0.3693359375, 0.37158203125000006]
accuracy_avg4 = [0.32373046875, 0.36650390625000007, 0.38154296874999993]
accuracy_avg5 = [0.3072265624999999, 0.3934570312499999, 0.405859375]
accuracy_avg6 = [0.33623046874999996, 0.3896484375, 0.40371093750000003]
accuracy_avg7 = [0.33916015625, 0.3904296875, 0.41044921874999996]
accuracy_avg8 = [0.34853515625, 0.4001953125, 0.42470703125]
accuracy_avg9 = [0.3453124999999999, 0.4091796874999999, 0.430078125]
accuracy_avg10 = [0.36015625, 0.4091796875, 0.43876953125000007]


all_accuracy_avgs = [accuracy_avg1, accuracy_avg2, accuracy_avg3, accuracy_avg4, accuracy_avg5,
                     accuracy_avg6, accuracy_avg7, accuracy_avg8, accuracy_avg9, accuracy_avg10]

sums = [sum(avg) for avg in all_accuracy_avgs]

    
"noise 2, mgn 2 = epsilon 0.32"
"noise 1.5, mgn 1.5 = epsilon 0.55"
"noise 1, mgn 1 = epsilon 1.37"
"noise 0.8, mgn 0.8 = epsilon 2.5"
"noise 0.65, mgn 0.65 = epsilon 4.5"
"noise 0.5, mgn 0.5 = epsilon 9.5"
"noise 0.4, mgn 0.4 = epsilon 19"
"noise 0.3, mgn 0.3 = epsilon 40"
"noise 0.25, mgn 0.25 = epsilon 66"
"noise 0.22, mgn 0.22 = epsilon 82"


epsilons = [0.32, 0.55, 1.37, 2.5, 4.5, 9.5, 19, 40, 66, 90]



accuracy_means = [sum(avg) / len(avg) for avg in all_accuracy_avgs]


# Plotting the data
plt.plot(epsilons, accuracy_means, marker='o', linestyle='-')

# Adding labels and title
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Accuracy as a function of epsilon')

# Setting x and y axis limits

plt.xscale('log')
plt.xlim(0.2, 200)
plt.ylim(0.29, 0.42)

# Display the plot
plt.show()

# %%
test = {"conv1": [0.743,0.918,1.093,1.111,1.123], "conv2": [0.585,0.713,0.879,0.969,1.001],
         "fc1": [0.558,0.687,0.792,0.826,0.874], "fc2": [0.558,0.687,0.792,0.826,0.874],
         "fc3": [0.380,0.422,0.440,0.471,0.500]}

data = []
for gradients in test.values():
    data.append(gradients)
    
print(data)
layer_names = ['Conv1', 'Conv2', 'Lin1', 'Lin2', 'Lin3']

plt.boxplot(data, labels=layer_names)

plt.xlabel('Layers')
plt.ylabel('Gradients')

plt.show()
# Out:
# [[0.743, 0.918, 1.093, 1.111, 1.123], [0.585, 0.713, 0.879, 0.969, 1.001], [0.558, 0.687, 0.792, 0.826, 0.874], [0.558, 0.687, 0.792, 0.826, 0.874], [0.38, 0.422, 0.44, 0.471, 0.5]]

# %%
"noise = 2"
"noise = 1.5"
"noise = 1"
"noise = 0.8"
"noise = 0.65"
"noise = 0.5"
"noise = 0.4"
"noise = 0.35"
"noise = 0.3"
"noise = 0.275"
"noise = 0.25"
"noise = 0.235"
"noise = 0.22"



epsilon_client1 = [0.31332803432113976, 0.5303885995895739, 1.3296579733290332, 2.4065261050648625,
                  4.327095413592455, 9.245804603036218, 17.61356616299025, 25.765450744410682, 39.48030897995137,
                   50.083312750664554, 65.5893730929181, 76.84801605856872, 90.52160505363459]

[0.29698581560283693, 0.30707003546099293, 0.33179576684397155, 0.3464372783687943,
                      0.3594027039007093, 0.3559535682624113, 0.3697501108156028, 0.36364140070921985,
                      0.3739611037234043, 0.3681432845744681, 0.36790780141843976, 0.3738526196369638,
                      0.37073359929078026]
[0.301580548679868, 0.30444255363036304, 0.33824515264026406, 0.3441496493399339,
                      0.3494740099009901, 0.3536123143564356, 0.35824051155115516, 0.36026454207920794,
                      0.36601433580858095, 0.37287283415841577, 0.3749742161716172, 0.36675808953900707,
                      0.37208642739273934]


plt.plot(epsilon_client1, accuracy_client1, marker='o', linestyle='-', label="Flat clipping with mgn = 2")

plt.plot(uniform_per_layer_clipping_epsilon1, uniform_per_layer_clipping_accuracy1, marker='o', linestyle='-',
        label ="uniform per layer clipping with mgn = 2/sqrt(14)")

plt.plot(per_layer1, accuracy_per_layer1, marker='o', linestyle='-',
        label ="per layer clipping")


plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Accuracy as a function of epsilon')


#plt.xscale('log')
plt.xlim(-1, 100)
plt.ylim(0.28, 0.42)

# Display the plot

plt.legend()
plt.show()



plt.plot(epsilon_client2, accuracy_client2, marker='o', linestyle='-', label="Flat clipping with mgn = 2")

plt.plot(uniform_per_layer_clipping_epsilon2, uniform_per_layer_clipping_accuracy2, marker='o', linestyle='-',
        label ="uniform per layer clipping with mgn = 2/sqrt(14)")

plt.plot(per_layer2, accuracy_per_layer2, marker='o', linestyle='-',
        label ="per layer clipping")


plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.title('Accuracy as a function of epsilon')


#plt.xscale('log')
plt.xlim(-1, 100)
plt.ylim(0.28, 0.42)
plt.legend()
plt.show()

# %%
import math
2/math.sqrt(14)
# Out:
# 0.5345224838248488

# %%
test = [2/math.sqrt(5), 2/math.sqrt(5), 2/math.sqrt(5), 2/math.sqrt(5), 2/math.sqrt(5)]

acc=0
for i in test:
    acc += i*i

print(acc)
# Out:
# 3.9999999999999996

# %%
test2 = [1.2, 1.1, 1, 0.5, 0.3]

acc2=0
for i in test2:
    acc2 += i*i

print(acc2)
# Out:
# 3.99

# %%
4-(36/14)
# Out:
# 1.4285714285714284

# %%
print(1.15/1)
print(1/0.9)
print(1)
print(0.9/0.5)
# Out:
# 1.15
# 1.1111111111111112
# 1
# 1.8

# %%
from sympy import symbols, Eq, solve

a, b, c, d, e = symbols('a b c d e')

eq1_new = Eq(a, b * 1.15)
eq2_new = Eq(b, c * 1.1111111111111112)
eq3_new = Eq(c, d)
eq4_new = Eq(d, e * 1.8)
eq5_new = Eq(a**2 + b**2 + c**2 + d**2 + e**2, 1.4285714285714284)

solutions_new = solve((eq1_new, eq2_new, eq3_new, eq4_new, eq5_new), (a, b, c, d, e))
solutions_new
# Out:
# [(-0.671293256841709,
#   -0.583733266818877,
#   -0.525359940136989,
#   -0.525359940136989,
#   -0.291866633409439),
#  (0.671293256841709,
#   0.583733266818877,
#   0.525359940136989,
#   0.525359940136989,
#   0.291866633409439)]

# %%
4/14
# Out:
# 0.2857142857142857

# %%
acc = 0



l = [0.534522,0.534522,0.534522,0.534522,0.534522,0.534522,0.534522,0.534522,0.534522]

for i in l:
    print(i)
    acc += i**2
    
print(4-acc)
# Out:
# 0.534522
# 0.534522
# 0.534522
# 0.534522
# 0.534522
# 0.534522
# 0.534522
# 0.534522
# 0.534522
# 1.4285760836439998

# %%
((2/math.sqrt(14))*(2/math.sqrt(14)))*14
# Out:
# 4.000000000000001
